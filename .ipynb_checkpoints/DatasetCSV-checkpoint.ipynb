# %%
import numpy as np # linear algebra
import pandas as pd # data processing
from PIL import Image
import sys
import array
import os

# %%
columnNames = list()
columnNames.append('label')
for i in range(784):
    pixel = 'pixel'
    pixel += str(i)
    columnNames.append(pixel)
train_data = pd.DataFrame(columns = columnNames)
i=0
count=1
for dirname, _, filenames in os.walk('F:/Open CV/Belajar/Dataset/train/'):
    for filename in filenames:
        image_name = os.path.join(dirname, filename)
        label = dirname[dirname.rindex('/')+1:]
        img = Image.open(image_name)
        rawData = img.load()
        data = []
        data.append(label)
        #28 itu dimensionnya, 784 itu 28x28 
        for y in range(28):
            for x in range(28):
                data.append(rawData[x,y])
        k = 0
        train_data.loc[i] = [data[k] for k in range(785)]
        i = i+1
    count = count + 1

# %%
train_data.head()
# Out:
#   label pixel0 pixel1 pixel2 pixel3 pixel4 pixel5 pixel6 pixel7 pixel8  ...  \
# 0     1    255    255    255    255    252    255    255    254    252  ...
# 1     1    255    255    252    255    254    255    255    255    254  ...
# 2     1    252    255    253    254    255    253    255    255    252  ...
# 3     1    255    252    254    255    255    255    254    255      0  ...
# 4     1    255    253    255    255    254    255    253    255    255  ...
#
#   pixel774 pixel775 pixel776 pixel777 pixel778 pixel779 pixel780 pixel781  \
# 0      255      255      255      255      255      255      255      255
# 1      255      255      255      255      255      255      255      255
# 2      255      255      255      255      255      255      255      255
# 3      255      255      255      255      255      255      255      255
# 4      255      255      255      255      255      255      255      255
#
#   pixel782 pixel783
# 0      255      255
# 1      255      255
# 2      255      255
# 3      255      255
# 4      255      255
#
# [5 rows x 785 columns]

# %%
train_data.to_csv('train.csv',index=False)
train = train_data
